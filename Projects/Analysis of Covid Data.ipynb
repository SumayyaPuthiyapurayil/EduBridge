# %% [markdown]
# # Covid Analysis

# %%
 I have covid patients count data in each countries contains active cases,confirmed cases and recovered etc
I want to analysis the data inorder to find the following
1.to check which country has highest cases
2.which country has lowest cases
2.I have to plot kdeplot & pair plot of this covid data

# %%
import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # read file

# %%
C=pd.read_csv("C:/Users/AJAS AJ7/Desktop/Sumayya\data set covid/country_wise_latest.csv")

# %% [markdown]
# # view data

# %%
C
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %% [markdown]
# # Set the index

# %%
#C.set_index("name")

# %% [markdown]
# # give index a name

# %%
C.index.name = "SNo"
C
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# SNo
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# SNo
# ...

# %% [markdown]
# # get columns names

# %%
C.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %% [markdown]
# # rename the columns names

# %%
C.rename(columns = {" Country/Region":"Country"},inplace=True)
C
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# SNo
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# SNo
# ...

# %% [markdown]
# # to print top 5 records

# %%
C.head()
# Out:
#     Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# SNo
# 0      Afghanistan      36263    1269      25198    9796        106
# 1          Albania       4880     144       2745    1991        117
# 2          Algeria      27973    1163      18837    7973        616
# 3          Andorra        907      52        803      52         10
# 4           Angola        950      41        242     667         18
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# SNo
# 0            10             18                3.50                  69.49
# 1             6             63                2.95                  56.25
# 2             8            749                4.16                  67.34
# 3             0              0                5.73                  88.53
# 4             1              0                4.32                  25.47
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# SNo
# ...

# %% [markdown]
# # to print top 10 records

# %%
C.head(10)
# Out:
#           Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# SNo
# 0            Afghanistan      36263    1269      25198    9796        106
# 1                Albania       4880     144       2745    1991        117
# 2                Algeria      27973    1163      18837    7973        616
# 3                Andorra        907      52        803      52         10
# 4                 Angola        950      41        242     667         18
# 5    Antigua and Barbuda         86       3         65      18          4
# 6              Argentina     167416    3059      72575   91782       4890
# 7                Armenia      37390     711      26665   10014         73
# 8              Australia      15303     167       9311    5825        368
# 9                Austria      20558     713      18246    1599         86
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# SNo
# ...

# %% [markdown]
# # to check columns and rows

# %%
C.shape
# Out:
# (187, 15)

# %% [markdown]
# # to check the type of attributes

# %%
C.dtypes
# Out:
# Country/Region             object
# Confirmed                   int64
# Deaths                      int64
# Recovered                   int64
# Active                      int64
# New cases                   int64
# New deaths                  int64
# New recovered               int64
# Deaths / 100 Cases        float64
# Recovered / 100 Cases     float64
# Deaths / 100 Recovered    float64
# Confirmed last week         int64
# 1 week change               int64
# 1 week % increase         float64
# WHO Region                 object
# dtype: object

# %% [markdown]
# # to check the number of diamension of the dataframe

# %%
C.ndim
# Out:
# 2

# %% [markdown]
# # to check the size of the data

# %%
C.size
# Out:
# 2805

# %% [markdown]
# # to get the index

# %%
C.index
# Out:
# RangeIndex(start=0, stop=187, step=1, name='SNo')

# %% [markdown]
# # to check datatype is empty or not

# %%
C.empty
# Out:
# False

# %% [markdown]
# # to get the column names

# %%
C.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %% [markdown]
# # print info of dataset

# %%
C.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    int64
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               187 non-null    int64
#  6   New deaths              187 non-null    int64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    int64
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
# ...

# %% [markdown]
# # to print statistical info

# %%
C.describe()
# Out:
#           Confirmed         Deaths     Recovered        Active     New cases  \
# count  1.870000e+02     187.000000  1.870000e+02  1.870000e+02    187.000000
# mean   8.813094e+04    3497.518717  5.063148e+04  3.400194e+04   1222.957219
# std    3.833187e+05   14100.002482  1.901882e+05  2.133262e+05   5710.374790
# min    1.000000e+01       0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%    1.114000e+03      18.500000  6.265000e+02  1.415000e+02      4.000000
# 50%    5.059000e+03     108.000000  2.815000e+03  1.600000e+03     49.000000
# 75%    4.046050e+04     734.000000  2.260600e+04  9.149000e+03    419.500000
# max    4.290259e+06  148011.000000  1.846641e+06  2.816444e+06  56336.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count   187.000000     187.000000          187.000000             187.000000
# mean     28.957219     933.812834            3.019519              64.820535
# ...

# %%
C.describe(include="all")
# Out:
#        Country/Region     Confirmed         Deaths     Recovered  \
# count             187  1.870000e+02     187.000000  1.870000e+02
# unique            187           NaN            NaN           NaN
# top           Albania           NaN            NaN           NaN
# freq                1           NaN            NaN           NaN
# mean              NaN  8.813094e+04    3497.518717  5.063148e+04
# std               NaN  3.833187e+05   14100.002482  1.901882e+05
# min               NaN  1.000000e+01       0.000000  0.000000e+00
# 25%               NaN  1.114000e+03      18.500000  6.265000e+02
# 50%               NaN  5.059000e+03     108.000000  2.815000e+03
# 75%               NaN  4.046050e+04     734.000000  2.260600e+04
# max               NaN  4.290259e+06  148011.000000  1.846641e+06
#
#               Active     New cases   New deaths  New recovered  \
# count   1.870000e+02    187.000000   187.000000     187.000000
# ...

# %% [markdown]
# # to describe a specific column

# %%
C.Deaths.describe()
# Out:
# count       187.000000
# mean       3497.518717
# std       14100.002482
# min           0.000000
# 25%          18.500000
# 50%         108.000000
# 75%         734.000000
# max      148011.000000
# Name: Deaths, dtype: float64

# %% [markdown]
# # To check if there is any missing values

# %%
C.isna()
# Out:
#      Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# SNo
# 0             False      False   False      False   False      False
# 1             False      False   False      False   False      False
# 2             False      False   False      False   False      False
# 3             False      False   False      False   False      False
# 4             False      False   False      False   False      False
# ..              ...        ...     ...        ...     ...        ...
# 182           False      False   False      False   False      False
# 183           False      False   False      False   False      False
# 184           False      False   False      False   False      False
# 185           False      False   False      False   False      False
# 186           False      False   False      False   False      False
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# SNo
# ...

# %%
C.isnull()
# Out:
#      Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# SNo
# 0             False      False   False      False   False      False
# 1             False      False   False      False   False      False
# 2             False      False   False      False   False      False
# 3             False      False   False      False   False      False
# 4             False      False   False      False   False      False
# ..              ...        ...     ...        ...     ...        ...
# 182           False      False   False      False   False      False
# 183           False      False   False      False   False      False
# 184           False      False   False      False   False      False
# 185           False      False   False      False   False      False
# 186           False      False   False      False   False      False
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# SNo
# ...

# %% [markdown]
# # sum of missing value

# %%
C.isna().sum()
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %%
C.isnull().sum()
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %% [markdown]
# # drop the column

# %%
C.drop("WHO Region",axis=1,inplace=True)
C
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# SNo
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# SNo
# ...

# %% [markdown]
# # to check duplicate value

# %%
C.duplicated()
# Out:
# SNo
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 182    False
# 183    False
# 184    False
# 185    False
# 186    False
# Length: 187, dtype: bool

# %% [markdown]
# # to check sum of duplicate values

# %%
C.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # to check number of unique values in a dataset

# %%
C.nunique()
# Out:
# Country/Region            187
# Confirmed                 184
# Deaths                    150
# Recovered                 178
# Active                    173
# New cases                 122
# New deaths                 38
# New recovered             103
# Deaths / 100 Cases        145
# Recovered / 100 Cases     177
# Deaths / 100 Recovered    155
# Confirmed last week       183
# 1 week change             162
# 1 week % increase         169
# dtype: int64

# %%
C.Confirmed.unique()
# Out:
# array([  36263,    4880,   27973,     907,     950,      86,  167416,
#          37390,   15303,   20558,   30446,     382,   39482,  226225,
#            110,   67251,   66428,      48,    1770,      99,   71181,
#          10498,     739, 2442375,     141,   10621,    1100,     350,
#            378,    2328,     226,   17110,  116458,    4599,     922,
#         347923,   86783,  257101,     354,    3200,    8844,   15841,
#          15655,    4881,    2532,    1060,   15516,   13761,    5059,
#             18,   64156,   81161,   92482,   15035,    3071,     265,
#           2034,    2316,   14547,      27,    7398,  220352,    7189,
#            326,    1137,  207112,   33624,    4227,      14,      23,
#          45309,    7055,    1954,     389,    7340,      12,   39741,
#           4448,    1854, 1480073,  100303,  293606,  112585,   25892,
#          63985,  246286,     853,   31142,    1176,   84648,   17975,
# ...

# %% [markdown]
# # count the the values of a column

# %%
C.Confirmed.value_counts()
# Out:
# 10621    2
# 24       2
# 86       2
# 2305     1
# 1455     1
#         ..
# 15988    1
# 674      1
# 350      1
# 2513     1
# 86783    1
# Name: Confirmed, Length: 184, dtype: int64

# %%
C["Confirmed"].value_counts()
# Out:
# 10621    2
# 24       2
# 86       2
# 2305     1
# 1455     1
#         ..
# 15988    1
# 674      1
# 350      1
# 2513     1
# 86783    1
# Name: Confirmed, Length: 184, dtype: int64

# %%
C["Confirmed"].value_counts()
# Out:
# 10621    2
# 24       2
# 86       2
# 2305     1
# 1455     1
#         ..
# 15988    1
# 674      1
# 350      1
# 2513     1
# 86783    1
# Name: Confirmed, Length: 184, dtype: int64

# %% [markdown]
# # maximum values using sort function

# %%
#### to show highest top 5 records with highest Cases

# %%
C.sort_values("Confirmed",ascending=False).head(5)
# Out:
#     Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# SNo
# 173             US    4290259  148011    1325804  2816444      56336
# 23          Brazil    2442375   87618    1846641   508116      23284
# 79           India    1480073   33408     951166   495499      44457
# 138         Russia     816680   13334     602249   201097       5607
# 154   South Africa     452529    7067     274925   170537       7096
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# SNo
# 173        1076          27941                3.45                  30.90
# 23          614          33728                3.59                  75.61
# 79          637          33598                2.26                  64.26
# 138          85           3077                1.63                  73.74
# 154         298           9848                1.56                  60.75
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# SNo
# ...

# %% [markdown]
# # Minimum using sort functions

# %% [markdown]
# # top 5 records with lowest cases

# %%
C.sort_values("Confirmed",ascending=True).head(5)
# Out:
#             Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# SNo
# 183         Western Sahara         10       1          8       1          0
# 75                Holy See         12       0         12       0          0
# 68               Greenland         14       0         13       1          1
# 140  Saint Kitts and Nevis         17       0         15       2          0
# 49                Dominica         18       0         18       0          0
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# SNo
# 183           0              0                10.0                  80.00
# 75            0              0                 0.0                 100.00
# 68            0              0                 0.0                  92.86
# 140           0              0                 0.0                  88.24
# 49            0              0                 0.0                 100.00
#
# ...

# %% [markdown]
# # to filter records based on specific values

# %% [markdown]
# # to view the records of Greenland

# %%
C_Greenland = C[C["Country/Region"]=="Greenland"]
C_Greenland
# Out:
#     Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# SNo
# 68       Greenland         14       0         13       1          1
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# SNo
# 68            0              0                 0.0                  92.86
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# SNo
# 68                      0.0                   13              1
#
#      1 week % increase
# SNo
# 68                7.69

# %% [markdown]
# # find maximum values using sort function on a filtered dataset

# %%
C_Greenland.sort_values("Confirmed",ascending=False).head(5)
# Out:
#     Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# SNo
# 68       Greenland         14       0         13       1          1
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# SNo
# 68            0              0                 0.0                  92.86
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# SNo
# 68                      0.0                   13              1
#
#      1 week % increase
# SNo
# 68                7.69

# %%
C
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# SNo
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# SNo
# ...

# %%
C.dtypes
# Out:
# Country/Region             object
# Confirmed                   int64
# Deaths                      int64
# Recovered                   int64
# Active                      int64
# New cases                   int64
# New deaths                  int64
# New recovered               int64
# Deaths / 100 Cases        float64
# Recovered / 100 Cases     float64
# Deaths / 100 Recovered    float64
# Confirmed last week         int64
# 1 week change               int64
# 1 week % increase         float64
# dtype: object

# %% [markdown]
# # grouping different types of cases as per 1 week change

# %%
C_1weekchange = C.groupby(["1 week change"]).agg({"Confirmed":"sum","Deaths":"sum"})
C_1weekchange
# Out:
#                Confirmed  Deaths
# 1 week change
# -47                 1176      11
#  0                  4637     119
#  1                   402      10
#  2                  1898      22
#  4                   110       7
# ...                  ...     ...
#  53096            257101    8777
#  78901            452529    7067
#  323729          2442375   87618
#  324735          1480073   33408
#  455582          4290259  148011
#
# [162 rows x 2 columns]

# %% [markdown]
# # check the relationsship between data

# %%
C.corr()
# Out:
#                         Confirmed    Deaths  Recovered    Active  New cases  \
# Confirmed                1.000000  0.934698   0.906377  0.927018   0.909720
# Deaths                   0.934698  1.000000   0.832098  0.871586   0.806975
# Recovered                0.906377  0.832098   1.000000  0.682103   0.818942
# Active                   0.927018  0.871586   0.682103  1.000000   0.851190
# New cases                0.909720  0.806975   0.818942  0.851190   1.000000
# New deaths               0.871683  0.814161   0.820338  0.781123   0.935947
# New recovered            0.859252  0.765114   0.919203  0.673887   0.914765
# Deaths / 100 Cases       0.063550  0.251565   0.048438  0.054380   0.020104
# Recovered / 100 Cases   -0.064815 -0.114529   0.026610 -0.132618  -0.078666
# Deaths / 100 Recovered   0.025175  0.169006  -0.027277  0.058386  -0.011637
# Confirmed last week      0.999127  0.939082   0.899312  0.931459   0.896084
# ...

# %% [markdown]
# # to print random data

# %%
C.sample(5)
# Out:
#         Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# SNo
# 54   Equatorial Guinea       3071      51        842    2178          0
# 160           Suriname       1483      24        925     534         44
# 56             Estonia       2034      69       1923      42          0
# 67              Greece       4227     202       1374    2651         34
# 109         Mauritania       6208     156       4653    1399         37
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# SNo
# 54            0              0                1.66                  27.42
# 160           1             35                1.62                  62.37
# 56            0              1                3.39                  94.54
# 67            0              0                4.78                  32.51
# 109           0            223                2.51                  74.95
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# SNo
# ...

# %% [markdown]
# # return rows as numpy ndiamensional array

# %%
C.values
# Out:
# array([['Afghanistan', 36263, 1269, ..., 35526, 737, 2.07],
#        ['Albania', 4880, 144, ..., 4171, 709, 17.0],
#        ['Algeria', 27973, 1163, ..., 23691, 4282, 18.07],
#        ...,
#        ['Yemen', 1691, 483, ..., 1619, 72, 4.45],
#        ['Zambia', 4552, 140, ..., 3326, 1226, 36.86],
#        ['Zimbabwe', 2704, 36, ..., 1713, 991, 57.85]], dtype=object)

# %% [markdown]
# # mean

# %%
C.mean()
# Out:
# Confirmed                 8.813094e+04
# Deaths                    3.497519e+03
# Recovered                 5.063148e+04
# Active                    3.400194e+04
# New cases                 1.222957e+03
# New deaths                2.895722e+01
# New recovered             9.338128e+02
# Deaths / 100 Cases        3.019519e+00
# Recovered / 100 Cases     6.482053e+01
# Deaths / 100 Recovered             inf
# Confirmed last week       7.868248e+04
# 1 week change             9.448460e+03
# 1 week % increase         1.360620e+01
# dtype: float64

# %% [markdown]
# # max

# %%
C.max()
# Out:
# Country/Region            Zimbabwe
# Confirmed                  4290259
# Deaths                      148011
# Recovered                  1846641
# Active                     2816444
# New cases                    56336
# New deaths                    1076
# New recovered                33728
# Deaths / 100 Cases           28.56
# Recovered / 100 Cases        100.0
# Deaths / 100 Recovered         inf
# Confirmed last week        3834677
# 1 week change               455582
# 1 week % increase           226.32
# dtype: object

# %% [markdown]
# # min

# %%
C.min()
# Out:
# Country/Region            Afghanistan
# Confirmed                          10
# Deaths                              0
# Recovered                           0
# Active                              0
# New cases                           0
# New deaths                          0
# New recovered                       0
# Deaths / 100 Cases                0.0
# Recovered / 100 Cases             0.0
# Deaths / 100 Recovered            0.0
# Confirmed last week                10
# 1 week change                     -47
# 1 week % increase               -3.84
# dtype: object

# %% [markdown]
# # to get the column names

# %%
C.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase'],
#       dtype='object')

# %% [markdown]
# # Check if there is exists 0 or negative values in column

# %%
print((C==0).sum()[(C==0).sum() > 0])
# Out:
# Deaths                    17
# Recovered                  6
# Active                     5
# New cases                 33
# New deaths                91
# New recovered             61
# Deaths / 100 Cases        17
# Recovered / 100 Cases      6
# Deaths / 100 Recovered    17
# 1 week change             12
# 1 week % increase         12
# dtype: int64

# %% [markdown]
# # replace null value with zero

# %%
C["New recovered"].fillna(0,inplace=True)
C
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# SNo
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# SNo
# ...

# %% [markdown]
# # mean

# %%
mean=C.mean
C
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# SNo
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# SNo
# ...

# %% [markdown]
# # add a column in dataframe with null value

# %%
C["NewColumn"] = np.nan
C
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# SNo
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# SNo
# ...

# %% [markdown]
# # fill the new column with zero using fillna

# %%
C["NewColumn"].fillna(0,inplace=True)

# %%
C
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# SNo
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# SNo
# ...

# %% [markdown]
# # replace zero with null

# %%
C["NewColumn"] = np.nan
C
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# SNo
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# SNo
# ...

# %% [markdown]
# # rename a column

# %%
C.rename(columns = {"NewColumn":"Remarks"},inplace=True)
C
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# SNo
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# SNo
# ...

# %% [markdown]
# # Delete Column

# %%
C.drop("Remarks",axis=1,inplace=True)
C
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# SNo
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# SNo
# ...

# %% [markdown]
# # Data Visualisation

# %% [markdown]
# # kdeplot

# %%
sns.kdeplot(C["Active"])
plt.show()

# %%
sns.kdeplot(C["Active"],color="green",shade=True)
plt.show()

# %%
 sns.kdeplot(C["Active"],color="green",vertical=True,shade=True)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)

# %%
sns.kdeplot(C["Active"],C["Deaths"],color="green",shade=True)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.pairplot(C, diag_kind="kde")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(C, diag_kind="hist",kind= "reg")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-1dc964f6048b> in <module>
# ----> 1 sns.pairplot(C, diag_kind="hist",kind= "reg")
#       2 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2017     diag_kws.setdefault("legend", False)
#    2018     if diag_kind == "hist":
# -> 2019         grid.map_diag(histplot, **diag_kws)
#    2020     elif diag_kind == "kde":
# ...

# %% [markdown]
# # Conclusion

# %% [markdown]
#  Afghanistan has lowest cases and Zimbawe has highest cases.
