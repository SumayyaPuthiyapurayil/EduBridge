# %% [markdown]
# # Analysis & Visualization of Asia Population 2020

# %%
I have the data of a Asia Population 2020 firm which contains population,density,..etc of countries   
I want to analysis the data inorder to find the following

1.Which countries have highest population?
2.Which countries have lowest population?
3.Plot a graph of population vs year change
4.I need Pair plot,kde plot & violin plot of this data

# %% [markdown]
# ### import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### read file

# %%
AP=pd.read_csv("C:/Users/AJAS AJ7/Desktop/Sumayya\Kaggle Datsets/AsiaPopulation2020.csv")

# %% [markdown]
# ### view data

# %%
AP
# Out:
#                  Country  Population  YearlyChange  NetChange  Density  \
# 0            Afghanistan    38928346          2.33     886592       60
# 1                Armenia     2963243          0.19       5512      104
# 2             Azerbaijan    10139177          0.91      91459      123
# 3                Bahrain     1701575          3.68      60403     2239
# 4             Bangladesh   164689383          1.01    1643222     1265
# 5                 Bhutan      771608          1.12       8516       20
# 6                 Brunei      437479          0.97       4194       83
# 7               Cambodia    16718965          1.41     232423       95
# 8                  China  1439323776          0.39    5540090      153
# 9                 Cyprus     1207359          0.73       8784      131
# 10               Georgia     3989167         -0.19      -7598       57
# 11             Hong Kong     7496981          0.82      60827     7140
# ...

# %% [markdown]
# ### Set the index

# %%
#AP.set_index("name")

# %% [markdown]
# ### give index a name

# %%
AP.index.name = "SNo"
AP
# Out:
#                   Country  Population  YearlyChange  NetChange  Density  \
# SNo
# 0             Afghanistan    38928346          2.33     886592       60
# 1                 Armenia     2963243          0.19       5512      104
# 2              Azerbaijan    10139177          0.91      91459      123
# 3                 Bahrain     1701575          3.68      60403     2239
# 4              Bangladesh   164689383          1.01    1643222     1265
# 5                  Bhutan      771608          1.12       8516       20
# 6                  Brunei      437479          0.97       4194       83
# 7                Cambodia    16718965          1.41     232423       95
# 8                   China  1439323776          0.39    5540090      153
# 9                  Cyprus     1207359          0.73       8784      131
# 10                Georgia     3989167         -0.19      -7598       57
# 11              Hong Kong     7496981          0.82      60827     7140
# ...

# %% [markdown]
# ### get columns names

# %%
AP.columns
# Out:
# Index(['Country', 'Population', 'YearlyChange', 'NetChange', 'Density',
#        'LandArea', 'Migrants', 'FertRate', 'MedAge', 'UrbanPop', 'WorldShare'],
#       dtype='object')

# %% [markdown]
# ### rename the columns names

# %%
AP.rename(columns = {" Country":"Country","Population":"Population"},inplace=True)
AP
# Out:
#                   Country  Population  YearlyChange  NetChange  Density  \
# SNo
# 0             Afghanistan    38928346          2.33     886592       60
# 1                 Armenia     2963243          0.19       5512      104
# 2              Azerbaijan    10139177          0.91      91459      123
# 3                 Bahrain     1701575          3.68      60403     2239
# 4              Bangladesh   164689383          1.01    1643222     1265
# 5                  Bhutan      771608          1.12       8516       20
# 6                  Brunei      437479          0.97       4194       83
# 7                Cambodia    16718965          1.41     232423       95
# 8                   China  1439323776          0.39    5540090      153
# 9                  Cyprus     1207359          0.73       8784      131
# 10                Georgia     3989167         -0.19      -7598       57
# 11              Hong Kong     7496981          0.82      60827     7140
# ...

# %% [markdown]
# ### to print top 5 records

# %%
AP.head()
# Out:
#          Country  Population  YearlyChange  NetChange  Density  LandArea  \
# SNo
# 0    Afghanistan    38928346          2.33     886592       60    652860
# 1        Armenia     2963243          0.19       5512      104     28470
# 2     Azerbaijan    10139177          0.91      91459      123     82658
# 3        Bahrain     1701575          3.68      60403     2239       760
# 4     Bangladesh   164689383          1.01    1643222     1265    130170
#
#      Migrants  FertRate  MedAge  UrbanPop  WorldShare
# SNo
# 0      -62920       4.6      18      25.0        0.50
# 1       -4998       1.8      35      63.0        0.04
# 2        1200       2.1      32      56.0        0.13
# 3       47800       2.0      32      89.0        0.02
# 4     -369501       2.1      28      39.0        2.11

# %% [markdown]
# ### to print top 10 records

# %%
AP.head(10)
# Out:
#          Country  Population  YearlyChange  NetChange  Density  LandArea  \
# SNo
# 0    Afghanistan    38928346          2.33     886592       60    652860
# 1        Armenia     2963243          0.19       5512      104     28470
# 2     Azerbaijan    10139177          0.91      91459      123     82658
# 3        Bahrain     1701575          3.68      60403     2239       760
# 4     Bangladesh   164689383          1.01    1643222     1265    130170
# 5         Bhutan      771608          1.12       8516       20     38117
# 6         Brunei      437479          0.97       4194       83      5270
# 7       Cambodia    16718965          1.41     232423       95    176520
# 8          China  1439323776          0.39    5540090      153   9388211
# 9         Cyprus     1207359          0.73       8784      131      9240
#
#      Migrants  FertRate  MedAge  UrbanPop  WorldShare
# SNo
# 0      -62920       4.6      18      25.0        0.50
# ...

# %% [markdown]
# ### to check columns and rows

# %%
AP.shape
# Out:
# (51, 11)

# %% [markdown]
# ### to check the type of attributes

# %%
AP.dtypes
# Out:
# Country          object
# Population        int64
# YearlyChange    float64
# NetChange         int64
# Density           int64
# LandArea          int64
# Migrants          int64
# FertRate        float64
# MedAge            int64
# UrbanPop        float64
# WorldShare      float64
# dtype: object

# %% [markdown]
# ### to check the number of diamension of the dataframe

# %%
AP.ndim
# Out:
# 2

# %% [markdown]
# ### to check the size of the data

# %%
AP.size
# Out:
# 561

# %% [markdown]
# ### to get the index

# %%
AP.index
# Out:
# RangeIndex(start=0, stop=51, step=1, name='SNo')

# %% [markdown]
# ### to check datatype is empty or not

# %%
AP.empty
# Out:
# False

# %% [markdown]
# ### to get the column names

# %%
AP.columns
# Out:
# Index(['Country', 'Population', 'YearlyChange', 'NetChange', 'Density',
#        'LandArea', 'Migrants', 'FertRate', 'MedAge', 'UrbanPop', 'WorldShare'],
#       dtype='object')

# %% [markdown]
# ### print info of dataset

# %%
AP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       51 non-null     object
#  1   Population    51 non-null     int64
#  2   YearlyChange  51 non-null     float64
#  3   NetChange     51 non-null     int64
#  4   Density       51 non-null     int64
#  5   LandArea      51 non-null     int64
#  6   Migrants      51 non-null     int64
#  7   FertRate      51 non-null     float64
#  8   MedAge        51 non-null     int64
#  9   UrbanPop      47 non-null     float64
#  10  WorldShare    51 non-null     float64
# dtypes: float64(4), int64(6), object(1)
# memory usage: 4.5+ KB

# %% [markdown]
# ### to print statistical info

# %%
AP.describe()
# Out:
#          Population  YearlyChange     NetChange       Density      LandArea  \
# count  5.100000e+01     51.000000  5.100000e+01     51.000000  5.100000e+01
# mean   9.100107e+07      1.267843  7.781094e+05    997.647059  6.084928e+05
# std    2.748929e+08      0.822083  2.111831e+06   3321.752241  1.430488e+06
# min    4.374790e+05     -0.440000 -3.838400e+05      2.000000  3.000000e+01
# 25%    5.104020e+06      0.805000  4.749550e+04     73.500000  2.505500e+04
# 50%    1.671896e+07      1.300000  1.198730e+05    123.000000  1.433500e+05
# 75%    4.574584e+07      1.710000  5.367205e+05    357.500000  4.904100e+05
# max    1.439324e+09      3.680000  1.358663e+07  21645.000000  9.388211e+06
#
#             Migrants   FertRate     MedAge   UrbanPop  WorldShare
# count      51.000000  51.000000  51.000000  47.000000   51.000000
# mean   -33904.235294   2.331373  30.862745  58.446809    1.168039
# std    135241.664715   0.805603   6.785336  22.701090    3.526507
# ...

# %%
AP.describe(include="all")
# Out:
#         Country    Population  YearlyChange     NetChange       Density  \
# count        51  5.100000e+01     51.000000  5.100000e+01     51.000000
# unique       51           NaN           NaN           NaN           NaN
# top     Armenia           NaN           NaN           NaN           NaN
# freq          1           NaN           NaN           NaN           NaN
# mean        NaN  9.100107e+07      1.267843  7.781094e+05    997.647059
# std         NaN  2.748929e+08      0.822083  2.111831e+06   3321.752241
# min         NaN  4.374790e+05     -0.440000 -3.838400e+05      2.000000
# 25%         NaN  5.104020e+06      0.805000  4.749550e+04     73.500000
# 50%         NaN  1.671896e+07      1.300000  1.198730e+05    123.000000
# 75%         NaN  4.574584e+07      1.710000  5.367205e+05    357.500000
# max         NaN  1.439324e+09      3.680000  1.358663e+07  21645.000000
#
#             LandArea       Migrants   FertRate     MedAge   UrbanPop  \
# ...

# %% [markdown]
# ### to describe a specific column

# %%
AP.Population.describe()
# Out:
# count    5.100000e+01
# mean     9.100107e+07
# std      2.748929e+08
# min      4.374790e+05
# 25%      5.104020e+06
# 50%      1.671896e+07
# 75%      4.574584e+07
# max      1.439324e+09
# Name: Population, dtype: float64

# %% [markdown]
# ### To check if there is any missing values

# %%
AP.isna()
# Out:
#      Country  Population  YearlyChange  NetChange  Density  LandArea  \
# SNo
# 0      False       False         False      False    False     False
# 1      False       False         False      False    False     False
# 2      False       False         False      False    False     False
# 3      False       False         False      False    False     False
# 4      False       False         False      False    False     False
# 5      False       False         False      False    False     False
# 6      False       False         False      False    False     False
# 7      False       False         False      False    False     False
# 8      False       False         False      False    False     False
# 9      False       False         False      False    False     False
# 10     False       False         False      False    False     False
# 11     False       False         False      False    False     False
# ...

# %%
AP.isnull()
# Out:
#      Country  Population  YearlyChange  NetChange  Density  LandArea  \
# SNo
# 0      False       False         False      False    False     False
# 1      False       False         False      False    False     False
# 2      False       False         False      False    False     False
# 3      False       False         False      False    False     False
# 4      False       False         False      False    False     False
# 5      False       False         False      False    False     False
# 6      False       False         False      False    False     False
# 7      False       False         False      False    False     False
# 8      False       False         False      False    False     False
# 9      False       False         False      False    False     False
# 10     False       False         False      False    False     False
# 11     False       False         False      False    False     False
# ...

# %% [markdown]
# ### sum of missing value

# %%
AP.isna().sum()
# Out:
# Country         0
# Population      0
# YearlyChange    0
# NetChange       0
# Density         0
# LandArea        0
# Migrants        0
# FertRate        0
# MedAge          0
# UrbanPop        4
# WorldShare      0
# dtype: int64

# %%
AP.isnull().sum()
# Out:
# Country         0
# Population      0
# YearlyChange    0
# NetChange       0
# Density         0
# LandArea        0
# Migrants        0
# FertRate        0
# MedAge          0
# UrbanPop        4
# WorldShare      0
# dtype: int64

# %% [markdown]
# ### drop the column

# %%
AP.drop("WorldShare",axis=1,inplace=True)
AP
# Out:
#                   Country  Population  YearlyChange  NetChange  Density  \
# SNo
# 0             Afghanistan    38928346          2.33     886592       60
# 1                 Armenia     2963243          0.19       5512      104
# 2              Azerbaijan    10139177          0.91      91459      123
# 3                 Bahrain     1701575          3.68      60403     2239
# 4              Bangladesh   164689383          1.01    1643222     1265
# 5                  Bhutan      771608          1.12       8516       20
# 6                  Brunei      437479          0.97       4194       83
# 7                Cambodia    16718965          1.41     232423       95
# 8                   China  1439323776          0.39    5540090      153
# 9                  Cyprus     1207359          0.73       8784      131
# 10                Georgia     3989167         -0.19      -7598       57
# 11              Hong Kong     7496981          0.82      60827     7140
# ...

# %% [markdown]
# ### to check duplicate value

# %%
AP.duplicated()
# Out:
# SNo
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# dtype: bool

# %% [markdown]
# ### to check sum of duplicate values

# %%
AP.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### to check number of unique values in a dataset

# %%
AP.nunique()
# Out:
# Country         51
# Population      51
# YearlyChange    47
# NetChange       51
# Density         48
# LandArea        51
# Migrants        48
# FertRate        24
# MedAge          25
# UrbanPop        36
# dtype: int64

# %% [markdown]
# ### to get the unique values of a column

# %%
AP["Country"].unique()
# Out:
# array(['Afghanistan', 'Armenia', 'Azerbaijan', 'Bahrain', 'Bangladesh',
#        'Bhutan', 'Brunei', 'Cambodia', 'China', 'Cyprus', 'Georgia',
#        'Hong Kong', 'India', 'Indonesia', 'Iran', 'Iraq', 'Israel',
#        'Japan', 'Jordan', 'Kazakhstan', 'Kuwait', 'Kyrgyzstan', 'Laos',
#        'Lebanon', 'Macao', 'Malaysia', 'Maldives', 'Mongolia', 'Myanmar',
#        'Nepal', 'North Korea', 'Oman', 'Pakistan', 'Philippines', 'Qatar',
#        'Saudi Arabia', 'Singapore', 'South Korea', 'Sri Lanka',
#        'State of Palestine', 'Syria', 'Taiwan', 'Tajikistan', 'Thailand',
#        'Timor-Leste', 'Turkey', 'Turkmenistan', 'United Arab Emirates',
#        'Uzbekistan', 'Vietnam', 'Yemen'], dtype=object)

# %%
AP.Country.unique()
# Out:
# array(['Afghanistan', 'Armenia', 'Azerbaijan', 'Bahrain', 'Bangladesh',
#        'Bhutan', 'Brunei', 'Cambodia', 'China', 'Cyprus', 'Georgia',
#        'Hong Kong', 'India', 'Indonesia', 'Iran', 'Iraq', 'Israel',
#        'Japan', 'Jordan', 'Kazakhstan', 'Kuwait', 'Kyrgyzstan', 'Laos',
#        'Lebanon', 'Macao', 'Malaysia', 'Maldives', 'Mongolia', 'Myanmar',
#        'Nepal', 'North Korea', 'Oman', 'Pakistan', 'Philippines', 'Qatar',
#        'Saudi Arabia', 'Singapore', 'South Korea', 'Sri Lanka',
#        'State of Palestine', 'Syria', 'Taiwan', 'Tajikistan', 'Thailand',
#        'Timor-Leste', 'Turkey', 'Turkmenistan', 'United Arab Emirates',
#        'Uzbekistan', 'Vietnam', 'Yemen'], dtype=object)

# %% [markdown]
# ### count the the values of a column

# %%
AP.Country.value_counts()
# Out:
# Armenia                 1
# United Arab Emirates    1
# Kyrgyzstan              1
# Thailand                1
# Syria                   1
# Georgia                 1
# Saudi Arabia            1
# Mongolia                1
# Israel                  1
# Singapore               1
# Iran                    1
# Cyprus                  1
# Iraq                    1
# Afghanistan             1
# China                   1
# Laos                    1
# Turkmenistan            1
# Pakistan                1
# Malaysia                1
# Indonesia               1
# Oman                    1
# Sri Lanka               1
# South Korea             1
# Kuwait                  1
# Jordan                  1
# Taiwan                  1
# Turkey                  1
# Maldives                1
# Cambodia                1
# Timor-Leste             1
# Lebanon                 1
# Qatar                   1
# Vietnam                 1
# Myanmar                 1
# Bahrain                 1
# ...

# %%
AP["Country"].value_counts()
# Out:
# Armenia                 1
# United Arab Emirates    1
# Kyrgyzstan              1
# Thailand                1
# Syria                   1
# Georgia                 1
# Saudi Arabia            1
# Mongolia                1
# Israel                  1
# Singapore               1
# Iran                    1
# Cyprus                  1
# Iraq                    1
# Afghanistan             1
# China                   1
# Laos                    1
# Turkmenistan            1
# Pakistan                1
# Malaysia                1
# Indonesia               1
# Oman                    1
# Sri Lanka               1
# South Korea             1
# Kuwait                  1
# Jordan                  1
# Taiwan                  1
# Turkey                  1
# Maldives                1
# Cambodia                1
# Timor-Leste             1
# Lebanon                 1
# Qatar                   1
# Vietnam                 1
# Myanmar                 1
# Bahrain                 1
# ...

# %%
AP["Population"].value_counts()
# Out:
# 1439323776    1
# 5101414       1
# 1701575       1
# 54409800      1
# 3278290       1
# 97338579      1
# 5850342       1
# 7496981       1
# 38928346      1
# 6031200       1
# 9890402       1
# 6825445       1
# 437479        1
# 5106626       1
# 40222493      1
# 23816775      1
# 4270571       1
# 9537645       1
# 126476461     1
# 17500658      1
# 3989167       1
# 83992949      1
# 84339067      1
# 29825964      1
# 649335        1
# 51269185      1
# 21413249      1
# 10139177      1
# 18776707      1
# 33469203      1
# 25778816      1
# 109581078     1
# 771608        1
# 2881053       1
# 273523615     1
# 1380004385    1
# 6524195       1
# 29136808      1
# 69799978      1
# 1207359       1
# 2963243       1
# 32365999      1
# 1318445       1
# 34813871      1
# 8655535       1
# 164689383     1
# 7275560       1
# 220892340     1
# 16718965      1
# 540544        1
# 10203134      1
# Name: Population, dtype: int64

# %%
AP.Population.value_counts()
# Out:
# 1439323776    1
# 5101414       1
# 1701575       1
# 54409800      1
# 3278290       1
# 97338579      1
# 5850342       1
# 7496981       1
# 38928346      1
# 6031200       1
# 9890402       1
# 6825445       1
# 437479        1
# 5106626       1
# 40222493      1
# 23816775      1
# 4270571       1
# 9537645       1
# 126476461     1
# 17500658      1
# 3989167       1
# 83992949      1
# 84339067      1
# 29825964      1
# 649335        1
# 51269185      1
# 21413249      1
# 10139177      1
# 18776707      1
# 33469203      1
# 25778816      1
# 109581078     1
# 771608        1
# 2881053       1
# 273523615     1
# 1380004385    1
# 6524195       1
# 29136808      1
# 69799978      1
# 1207359       1
# 2963243       1
# 32365999      1
# 1318445       1
# 34813871      1
# 8655535       1
# 164689383     1
# 7275560       1
# 220892340     1
# 16718965      1
# 540544        1
# 10203134      1
# Name: Population, dtype: int64

# %% [markdown]
# ### maximum values using sort function

# %% [markdown]
# #### to show highest top 5 records with highest population

# %%
AP.sort_values("Population",ascending=False).head(5)
# Out:
#         Country  Population  YearlyChange  NetChange  Density  LandArea  \
# SNo
# 8         China  1439323776          0.39    5540090      153   9388211
# 12        India  1380004385          0.99   13586631      464   2973190
# 13    Indonesia   273523615          1.07    2898047      151   1811570
# 32     Pakistan   220892340          2.00    4327022      287    770880
# 4    Bangladesh   164689383          1.01    1643222     1265    130170
#
#      Migrants  FertRate  MedAge  UrbanPop
# SNo
# 8     -348399       1.7      38      61.0
# 12    -532687       2.2      28      35.0
# 13     -98955       2.3      30      56.0
# 32    -233379       3.6      23      35.0
# 4     -369501       2.1      28      39.0

# %%
AP.sort_values("Density",ascending=False).head(1)
# Out:
#     Country  Population  YearlyChange  NetChange  Density  LandArea  Migrants  \
# SNo
# 24    Macao      649335          1.39       8890    21645        30      5000
#
#      FertRate  MedAge  UrbanPop
# SNo
# 24        1.2      39       NaN

# %% [markdown]
# ### Minimum using sort functions

# %% [markdown]
# #### top 5 records with lowest population

# %%
AP.sort_values("Population",ascending=True).head(5)
# Out:
#       Country  Population  YearlyChange  NetChange  Density  LandArea  \
# SNo
# 6      Brunei      437479          0.97       4194       83      5270
# 26   Maldives      540544          1.81       9591     1802       300
# 24      Macao      649335          1.39       8890    21645        30
# 5      Bhutan      771608          1.12       8516       20     38117
# 9      Cyprus     1207359          0.73       8784      131      9240
#
#      Migrants  FertRate  MedAge  UrbanPop
# SNo
# 6           0       1.8      32      80.0
# 26      11370       1.9      30      35.0
# 24       5000       1.2      39       NaN
# 5         320       2.0      28      46.0
# 9        5000       1.3      37      67.0

# %%
AP.sort_values("Density",ascending=True).head(1)
# Out:
#       Country  Population  YearlyChange  NetChange  Density  LandArea  \
# SNo
# 27   Mongolia     3278290          1.65      53123        2   1553560
#
#      Migrants  FertRate  MedAge  UrbanPop
# SNo
# 27       -852       2.9      28      67.0

# %% [markdown]
# ### to filter records based on specific values

# %% [markdown]
# #### to view the records of Maldives

# %%
AP_Maldives = AP[AP["Country"]=="Maldives"]
AP_Maldives
# Out:
#       Country  Population  YearlyChange  NetChange  Density  LandArea  \
# SNo
# 26   Maldives      540544          1.81       9591     1802       300
#
#      Migrants  FertRate  MedAge  UrbanPop
# SNo
# 26      11370       1.9      30      35.0

# %% [markdown]
# ### find maximum values using sort function on a filtered dataset

# %%
AP_Maldives.sort_values("Density",ascending=False).head(5)
# Out:
#       Country  Population  YearlyChange  NetChange  Density  LandArea  \
# SNo
# 26   Maldives      540544          1.81       9591     1802       300
#
#      Migrants  FertRate  MedAge  UrbanPop
# SNo
# 26      11370       1.9      30      35.0

# %%
AP[AP["Country"]=="Maldives"].sort_values("Density",ascending=False).head(5)
# Out:
#       Country  Population  YearlyChange  NetChange  Density  LandArea  \
# SNo
# 26   Maldives      540544          1.81       9591     1802       300
#
#      Migrants  FertRate  MedAge  UrbanPop
# SNo
# 26      11370       1.9      30      35.0

# %%
AP
# Out:
#                   Country  Population  YearlyChange  NetChange  Density  \
# SNo
# 0             Afghanistan    38928346          2.33     886592       60
# 1                 Armenia     2963243          0.19       5512      104
# 2              Azerbaijan    10139177          0.91      91459      123
# 3                 Bahrain     1701575          3.68      60403     2239
# 4              Bangladesh   164689383          1.01    1643222     1265
# 5                  Bhutan      771608          1.12       8516       20
# 6                  Brunei      437479          0.97       4194       83
# 7                Cambodia    16718965          1.41     232423       95
# 8                   China  1439323776          0.39    5540090      153
# 9                  Cyprus     1207359          0.73       8784      131
# 10                Georgia     3989167         -0.19      -7598       57
# 11              Hong Kong     7496981          0.82      60827     7140
# ...

# %%
AP.dtypes
# Out:
# Country          object
# Population        int64
# YearlyChange    float64
# NetChange         int64
# Density           int64
# LandArea          int64
# Migrants          int64
# FertRate        float64
# MedAge            int64
# UrbanPop        float64
# dtype: object

# %% [markdown]
# ### grouping different types of cases as per the year change

# %%
AP_yearwise = AP.groupby(["YearlyChange"]).agg({"Population":"sum","Density":"sum"})
AP_yearwise
# Out:
#               Population  Density
# YearlyChange
# -0.44            6825445      667
# -0.30          126476461      347
# -0.19            3989167       57
#  0.09           51269185      527
#  0.18           23816775      673
#  0.19            2963243      104
#  0.25           69799978      137
#  0.39         1439323776      153
#  0.42           21413249      341
#  0.44           25778816      214
#  0.67           54409800       83
#  0.73            1207359      131
#  0.79            5850342     8358
#  0.82            7496981     7140
#  0.91          107477756      437
#  0.97             437479       83
#  0.99         1380004385      464
#  1.00           10203134      115
#  1.01          164689383     1265
#  1.07          273523615      151
#  1.09           84339067      110
#  1.12             771608       20
#  1.21           18776707        7
#  1.23            9890402      118
#  1.30          116358948      151
#  1.35          109581078      368
# ...

# %% [markdown]
# ### last record of the datewise data

# %%
AP_yearwise["Population"].iloc[-1]
# Out:
# 1701575

# %%
AP_yearwise["Density"].iloc[-1]
# Out:
# 2239

# %% [markdown]
# ### check the relationsship between data

# %%
AP.corr()
# Out:
#               Population  YearlyChange  NetChange   Density  LandArea  \
# Population      1.000000     -0.165332   0.886019 -0.067760  0.819242
# YearlyChange   -0.165332      1.000000  -0.026158 -0.005829 -0.118517
# NetChange       0.886019     -0.026158   1.000000 -0.073710  0.558477
# Density        -0.067760     -0.005829  -0.073710  1.000000 -0.110785
# LandArea        0.819242     -0.118517   0.558477 -0.110785  1.000000
# Migrants       -0.654649      0.015194  -0.694381  0.066598 -0.419407
# FertRate       -0.087700      0.615349   0.051295 -0.325564 -0.021931
# MedAge          0.061817     -0.645972  -0.121301  0.332054  0.071428
# UrbanPop       -0.120103     -0.084533  -0.219139  0.098259 -0.010478
#
#               Migrants  FertRate    MedAge  UrbanPop
# Population   -0.654649 -0.087700  0.061817 -0.120103
# YearlyChange  0.015194  0.615349 -0.645972 -0.084533
# NetChange    -0.694381  0.051295 -0.121301 -0.219139
# Density       0.066598 -0.325564  0.332054  0.098259
# ...

# %% [markdown]
# ### to print random data

# %%
AP.sample(5)
# Out:
#        Country  Population  YearlyChange  NetChange  Density  LandArea  \
# SNo
# 7     Cambodia    16718965          1.41     232423       95    176520
# 11   Hong Kong     7496981          0.82      60827     7140      1050
# 28     Myanmar    54409800          0.67     364380       83    653290
# 16      Israel     8655535          1.60     136158      400     21640
# 8        China  1439323776          0.39    5540090      153   9388211
#
#      Migrants  FertRate  MedAge  UrbanPop
# SNo
# 7      -30000       2.5      26      24.0
# 11      29308       1.3      45       NaN
# 28    -163313       2.2      29      31.0
# 16      10000       3.0      30      93.0
# 8     -348399       1.7      38      61.0

# %% [markdown]
# ### return rows as numpy ndiamensional array

# %%
AP.values
# Out:
# array([['Afghanistan', 38928346, 2.33, 886592, 60, 652860, -62920, 4.6,
#         18, 25.0],
#        ['Armenia', 2963243, 0.19, 5512, 104, 28470, -4998, 1.8, 35, 63.0],
#        ['Azerbaijan', 10139177, 0.91, 91459, 123, 82658, 1200, 2.1, 32,
#         56.0],
#        ['Bahrain', 1701575, 3.68, 60403, 2239, 760, 47800, 2.0, 32, 89.0],
#        ['Bangladesh', 164689383, 1.01, 1643222, 1265, 130170, -369501,
#         2.1, 28, 39.0],
#        ['Bhutan', 771608, 1.12, 8516, 20, 38117, 320, 2.0, 28, 46.0],
#        ['Brunei', 437479, 0.97, 4194, 83, 5270, 0, 1.8, 32, 80.0],
#        ['Cambodia', 16718965, 1.41, 232423, 95, 176520, -30000, 2.5, 26,
#         24.0],
#        ['China', 1439323776, 0.39, 5540090, 153, 9388211, -348399, 1.7,
#         38, 61.0],
#        ['Cyprus', 1207359, 0.73, 8784, 131, 9240, 5000, 1.3, 37, 67.0],
#        ['Georgia', 3989167, -0.19, -7598, 57, 69490, -10000, 2.1, 38,
#         58.0],
# ...

# %% [markdown]
# ### mean

# %%
AP.mean()
# Out:
# Population      9.100107e+07
# YearlyChange    1.267843e+00
# NetChange       7.781094e+05
# Density         9.976471e+02
# LandArea        6.084928e+05
# Migrants       -3.390424e+04
# FertRate        2.331373e+00
# MedAge          3.086275e+01
# UrbanPop        5.844681e+01
# dtype: float64

# %% [markdown]
# ### max

# %%
AP.max()
# Out:
# Country              Yemen
# Population      1439323776
# YearlyChange          3.68
# NetChange         13586631
# Density              21645
# LandArea           9388211
# Migrants            283922
# FertRate               4.6
# MedAge                  48
# UrbanPop              96.0
# dtype: object

# %% [markdown]
# ### min

# %%
AP.min()
# Out:
# Country         Afghanistan
# Population           437479
# YearlyChange          -0.44
# NetChange           -383840
# Density                   2
# LandArea                 30
# Migrants            -532687
# FertRate                1.1
# MedAge                   18
# UrbanPop               18.0
# dtype: object

# %% [markdown]
# ### to get the column names

# %%
AP.columns
# Out:
# Index(['Country', 'Population', 'YearlyChange', 'NetChange', 'Density',
#        'LandArea', 'Migrants', 'FertRate', 'MedAge', 'UrbanPop'],
#       dtype='object')

# %% [markdown]
# ### Check if there is exists 0 or negative values in columns

# %%
print((AP==0).sum()[(AP==0).sum() > 0])
# Out:
# Migrants    1
# dtype: int64

# %% [markdown]
# ### replace null value with zero

# %%
AP["Migrants"].fillna(0,inplace=True)
AP
# Out:
#                   Country  Population  YearlyChange  NetChange  Density  \
# SNo
# 0             Afghanistan    38928346          2.33     886592       60
# 1                 Armenia     2963243          0.19       5512      104
# 2              Azerbaijan    10139177          0.91      91459      123
# 3                 Bahrain     1701575          3.68      60403     2239
# 4              Bangladesh   164689383          1.01    1643222     1265
# 5                  Bhutan      771608          1.12       8516       20
# 6                  Brunei      437479          0.97       4194       83
# 7                Cambodia    16718965          1.41     232423       95
# 8                   China  1439323776          0.39    5540090      153
# 9                  Cyprus     1207359          0.73       8784      131
# 10                Georgia     3989167         -0.19      -7598       57
# 11              Hong Kong     7496981          0.82      60827     7140
# ...

# %% [markdown]
# ### add a column in dataframe with null value

# %%
mean=AP.mean
AP
# Out:
#                   Country  Population  YearlyChange  NetChange  Density  \
# SNo
# 0             Afghanistan    38928346          2.33     886592       60
# 1                 Armenia     2963243          0.19       5512      104
# 2              Azerbaijan    10139177          0.91      91459      123
# 3                 Bahrain     1701575          3.68      60403     2239
# 4              Bangladesh   164689383          1.01    1643222     1265
# 5                  Bhutan      771608          1.12       8516       20
# 6                  Brunei      437479          0.97       4194       83
# 7                Cambodia    16718965          1.41     232423       95
# 8                   China  1439323776          0.39    5540090      153
# 9                  Cyprus     1207359          0.73       8784      131
# 10                Georgia     3989167         -0.19      -7598       57
# 11              Hong Kong     7496981          0.82      60827     7140
# ...

# %%
AP["NewColumn"] = np.nan

# %%
AP
# Out:
#                   Country  Population  YearlyChange  NetChange  Density  \
# SNo
# 0             Afghanistan    38928346          2.33     886592       60
# 1                 Armenia     2963243          0.19       5512      104
# 2              Azerbaijan    10139177          0.91      91459      123
# 3                 Bahrain     1701575          3.68      60403     2239
# 4              Bangladesh   164689383          1.01    1643222     1265
# 5                  Bhutan      771608          1.12       8516       20
# 6                  Brunei      437479          0.97       4194       83
# 7                Cambodia    16718965          1.41     232423       95
# 8                   China  1439323776          0.39    5540090      153
# 9                  Cyprus     1207359          0.73       8784      131
# 10                Georgia     3989167         -0.19      -7598       57
# 11              Hong Kong     7496981          0.82      60827     7140
# ...

# %% [markdown]
# ### fill the new column with zero using fillna

# %%
AP["NewColumn"].fillna(0,inplace=True)

# %%
AP
# Out:
#                   Country  Population  YearlyChange  NetChange  Density  \
# SNo
# 0             Afghanistan    38928346          2.33     886592       60
# 1                 Armenia     2963243          0.19       5512      104
# 2              Azerbaijan    10139177          0.91      91459      123
# 3                 Bahrain     1701575          3.68      60403     2239
# 4              Bangladesh   164689383          1.01    1643222     1265
# 5                  Bhutan      771608          1.12       8516       20
# 6                  Brunei      437479          0.97       4194       83
# 7                Cambodia    16718965          1.41     232423       95
# 8                   China  1439323776          0.39    5540090      153
# 9                  Cyprus     1207359          0.73       8784      131
# 10                Georgia     3989167         -0.19      -7598       57
# 11              Hong Kong     7496981          0.82      60827     7140
# ...

# %% [markdown]
# ### replace zero with null

# %%
AP["NewColumn"] = np.nan
AP
# Out:
#                   Country  Population  YearlyChange  NetChange  Density  \
# SNo
# 0             Afghanistan    38928346          2.33     886592       60
# 1                 Armenia     2963243          0.19       5512      104
# 2              Azerbaijan    10139177          0.91      91459      123
# 3                 Bahrain     1701575          3.68      60403     2239
# 4              Bangladesh   164689383          1.01    1643222     1265
# 5                  Bhutan      771608          1.12       8516       20
# 6                  Brunei      437479          0.97       4194       83
# 7                Cambodia    16718965          1.41     232423       95
# 8                   China  1439323776          0.39    5540090      153
# 9                  Cyprus     1207359          0.73       8784      131
# 10                Georgia     3989167         -0.19      -7598       57
# 11              Hong Kong     7496981          0.82      60827     7140
# ...

# %%
AP
# Out:
#                   Country  Population  YearlyChange  NetChange  Density  \
# SNo
# 0             Afghanistan    38928346          2.33     886592       60
# 1                 Armenia     2963243          0.19       5512      104
# 2              Azerbaijan    10139177          0.91      91459      123
# 3                 Bahrain     1701575          3.68      60403     2239
# 4              Bangladesh   164689383          1.01    1643222     1265
# 5                  Bhutan      771608          1.12       8516       20
# 6                  Brunei      437479          0.97       4194       83
# 7                Cambodia    16718965          1.41     232423       95
# 8                   China  1439323776          0.39    5540090      153
# 9                  Cyprus     1207359          0.73       8784      131
# 10                Georgia     3989167         -0.19      -7598       57
# 11              Hong Kong     7496981          0.82      60827     7140
# ...

# %% [markdown]
# ### rename a column

# %%
AP.rename(columns = {"NewColumn":"Remarks"},inplace=True)
AP
# Out:
#                   Country  Population  YearlyChange  NetChange  Density  \
# SNo
# 0             Afghanistan    38928346          2.33     886592       60
# 1                 Armenia     2963243          0.19       5512      104
# 2              Azerbaijan    10139177          0.91      91459      123
# 3                 Bahrain     1701575          3.68      60403     2239
# 4              Bangladesh   164689383          1.01    1643222     1265
# 5                  Bhutan      771608          1.12       8516       20
# 6                  Brunei      437479          0.97       4194       83
# 7                Cambodia    16718965          1.41     232423       95
# 8                   China  1439323776          0.39    5540090      153
# 9                  Cyprus     1207359          0.73       8784      131
# 10                Georgia     3989167         -0.19      -7598       57
# 11              Hong Kong     7496981          0.82      60827     7140
# ...

# %%
AP.drop("Remarks",axis=1,inplace=True)
AP
# Out:
#                   Country  Population  YearlyChange  NetChange  Density  \
# SNo
# 0             Afghanistan    38928346          2.33     886592       60
# 1                 Armenia     2963243          0.19       5512      104
# 2              Azerbaijan    10139177          0.91      91459      123
# 3                 Bahrain     1701575          3.68      60403     2239
# 4              Bangladesh   164689383          1.01    1643222     1265
# 5                  Bhutan      771608          1.12       8516       20
# 6                  Brunei      437479          0.97       4194       83
# 7                Cambodia    16718965          1.41     232423       95
# 8                   China  1439323776          0.39    5540090      153
# 9                  Cyprus     1207359          0.73       8784      131
# 10                Georgia     3989167         -0.19      -7598       57
# 11              Hong Kong     7496981          0.82      60827     7140
# ...

# %% [markdown]
# ## Data Visualisation

# %% [markdown]
# ### Plot a graph population vs yearlychange

# %%
plt.bar(AP["YearlyChange"],AP["Population"],color="red")
plt.title("Population vs YearlyChange", fontsize=15, color="red")
plt.xlabel("YearlyChange", fontsize=15)
plt.ylabel("Population", fontsize=15)
plt.grid(True)
plt.show()

# %%
plt.bar(AP["FertRate"],AP["Population"],color="red")
plt.title("Population vs FertRate", fontsize=15, color="red")
plt.xlabel("FertRate", fontsize=15)
plt.ylabel("Population", fontsize=15)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(16,18))
sns.relplot(x="FertRate",y="Population",hue="Country",data=AP)
plt.show()

# %% [markdown]
# # CATPLOT

# %%
sns.catplot(x="FertRate",y="Population",col="Density",hue="Country",data=AP)
plt.show()

# %%
sns.catplot(x="FertRate",y="Population",col="Density",hue="Country",kind="boxen", data=AP)
plt.show()

# %%
sns.catplot(x="FertRate",y="Population",col="Density",hue="Country",kind="point", data=AP)
plt.show()

# %% [markdown]
# # kdeplot

# %%
sns.kdeplot(AP["Population"])
plt.show()

# %%
sns.kdeplot(AP["Density"],color="green",shade=True)
plt.show()

# %%
sns.kdeplot(AP["Density"],color="green",vertical=True,shade=True)
plt.show()

# %%
sns.kdeplot(AP["Population"],AP["Density"],color="green",shade=True)
plt.show()

# %%
sns.pairplot(AP)
plt.show()

# %%
sns.pairplot(AP, diag_kind="kde")
plt.show()

# %%
sns.pairplot(AP, diag_kind="kde",hue= "Country")
plt.show()

# %%
sns.pairplot(AP, diag_kind="hist",kind= "reg")
plt.show()

# %%
sns.set_style("darkgrid")
sns.stripplot(x="Density",y="Population",data=AP)
plt.show()

# %% [markdown]
# # Violin plot

# %%
sns.violinplot(x=AP.Density)
plt.show()

# %%
sns.violinplot(x="Density",y="Population",data=AP)
plt.show()

# %%
sns.violinplot(x="Density",y="Population",hue="Country",data=AP)
plt.show()

# %% [markdown]
# # Swarm plot
# A swarm plot can be drawn on its own,but it is also a good complement to a box or violin plot in cases
# where you want to show all observations along with some representatioin of the underlying distribution.
# This style of plot isnsometimes called a beeswarm.

# %%
sns.swarmplot(AP["Population"])
plt.show()

# %%
sns.swarmplot(x="Density",y="Population",data=AP)
plt.show()

# %%
sns.swarmplot(x="Density",y="Population",hue="Country",data=AP)
plt.show()

# %%
sns.swarmplot(x="Density",y="Population",hue="Country",dodge=True,data=AP)
plt.show()

# %%
Brunei = AP[AP.Country=="Brunei"]

sns.swarmplot(x=Bahrain.YearChange,y=Brunei.Population,color="green",size=4)
plt.show()

# %%
Brunei = AP[AP.Country=="Brunei"]


sns.violinplot(x=Bahrain.YearChange,y=Bahrain.Population,scale="width",inner=None,color="red")
sns.swarmplotx=Bahrain.YearChange,y=Bahrain.Population(,color="green",size=4)
plt.show()

# %% [markdown]
# # Box plot
# The seaborn boxplot is a very basic plot zboxplots are used to visualize distributions.
# Thats very useful when you want to compare data between two groups.
# Sometimes a boxplot is named a box-and-whisker plot.Any box shows the quartiles of the dataset while the whiskers extend to show the distributions.

# %%
sns.boxplot(AP["Density"])
plt.show()

# %%
sns.boxplot(x="Density",y="Population",hue="Country",width=0.7,dodge=True,data=AP)
plt.show()

# %%
sns.boxplot(x="Density",y="Population",color="green",data=AP)
plt.show()

# %%
Brunei = AP[AP.Country=="Brunei"]
sns.boxplot(x=Brunei.YearChange,y=Brunei.Population,color="red")
sns.swarmplot(x=Brunei.YearChange,y=Brunei.Population,color="green",size=4)
plt.show()

# %%
sns.catplot(x="YearChange",y="Population",col="Country",kind="swarm",size=3,data=AP)
plt.show()

# %% [markdown]
# # Heat map
# correlation

# %%
AP.corr
# Out:
# <bound method DataFrame.corr of                   Country  Population  YearlyChange  NetChange  Density  \
# SNo
# 0             Afghanistan    38928346          2.33     886592       60
# 1                 Armenia     2963243          0.19       5512      104
# 2              Azerbaijan    10139177          0.91      91459      123
# 3                 Bahrain     1701575          3.68      60403     2239
# 4              Bangladesh   164689383          1.01    1643222     1265
# 5                  Bhutan      771608          1.12       8516       20
# 6                  Brunei      437479          0.97       4194       83
# 7                Cambodia    16718965          1.41     232423       95
# 8                   China  1439323776          0.39    5540090      153
# 9                  Cyprus     1207359          0.73       8784      131
# 10                Georgia     3989167         -0.19      -7598       57
# ...

# %%
sns.heatmap(AP.corr())
plt.show()

# %%
sns.heatmap(AP.corr(),cmap="RdBu")
plt.show()

# %%
sns.heatmap(AP.corr(),cmap="RdBu",vmin=0,vmax=1)
plt.show()

# %%
sns.heatmap(AP.corr(),cmap="RdBu",annot=True)
plt.show()

# %%
sns.heatmap(AP.corr(),cmap="RdBu",annot=True,fmt=".1f")
plt.show()

# %%
sns.heatmap(AP.corr(),cmap="RdBu",linewidth=1)
plt.show()

# %%
sns.heatmap(AP.corr(),cmap="RdBu",linewidth=1,linecolor="yellow")
plt.show()

# %%
sns.heatmap(AP.corr(),cmap="RdBu",linewidth=1,linecolor="yellow",square=True)
plt.show()

# %% [markdown]
# # Dist plot
# Seaborn distplot lets you show a histogram with a line on it.This can be shown in all kinds of variations.
# A distplot plot a univariate distribution of observations.

# %%
sns.distplot(AP.Population)
plt.show()

# %%
sns.displot(AP.Population)
plt.show()

# %%
sns.distplot(AP.Population,color="green")
plt.show()

# %%
sns.distplot(AP.Population,color="green",hist=False)
plt.show()

# %%
sns.distplot(AP.Population,color="green",kde=False)
plt.show()

# %%
sns.distplot(AP.Population,color="green",bins=10)
plt.show()

# %%
AP
# Out:
#                   Country  Population  YearlyChange  NetChange  Density  \
# SNo
# 0             Afghanistan    38928346          2.33     886592       60
# 1                 Armenia     2963243          0.19       5512      104
# 2              Azerbaijan    10139177          0.91      91459      123
# 3                 Bahrain     1701575          3.68      60403     2239
# 4              Bangladesh   164689383          1.01    1643222     1265
# 5                  Bhutan      771608          1.12       8516       20
# 6                  Brunei      437479          0.97       4194       83
# 7                Cambodia    16718965          1.41     232423       95
# 8                   China  1439323776          0.39    5540090      153
# 9                  Cyprus     1207359          0.73       8784      131
# 10                Georgia     3989167         -0.19      -7598       57
# 11              Hong Kong     7496981          0.82      60827     7140
# ...

# %%
plt.figure(figsize=(8,3))
sns.distplot(AP.Population,
           bins=20,
           kde_kws={"lw":4,"color":"green"},
            hist_kws={"alpha":0.3,"color":"gray"}
            )
plt.xlabel("weight (lbs)",fontsize=16,labelpad=15)
plt.yticks([])
plt.show()

# %%
plt.figure(figsize=(8,10))
sns.relplot(x="Density",y="Population",hue="Country",data=AP)
plt.show()

# %%
sns.countplot(x="Density",data=AP,palette="coolwarm")
plt.show()

# %%
sns.countplot(x="Density",data=AP,palette="tab10")
plt.show()

# %%
plt.title("Country",fontsize=20)
AP["Country"].value_counts().plot.pie(autopct="%1.1f%%",shadow=True)
plt.show()

# %%
AP.groupby("Country")[["Population","Density"]].sum().plot.bar(color=["red","blue"],figsize=(8,5))
plt.ylabel("Population and Density")
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.title("Country wise Population")
sns.barplot(x="Density",y="Population",data=AP,palette="coolwarm_r")
plt.xlabel("Density",fontsize=15)
plt.show()

# %%
plt.figure(figsize=(22,9))
sns.countplot(x="Population",data=AP,palette="rocket_r",order=AP["Population"].value_counts().index)
plt.xlabel("Density",fontsize=25)
plt.xticks(rotation=70)
plt.show()

# %% [markdown]
# # Conclusion

# %%
I have analysed this Asia Population 2020 . China is the highest population country in Asia.Brunei is the lowest population country in Asia.I got more details.I have plotted graphs.

# %% [markdown]
# # LINEAR REGRESSION

# %%
AP2=AP.drop(["Country","NetChange","Density","LandArea","Migrants","FertRate","MedAge","UrbanPop"],axis=1)
AP2
# Out:
#      Population  YearlyChange
# SNo
# 0      38928346          2.33
# 1       2963243          0.19
# 2      10139177          0.91
# 3       1701575          3.68
# 4     164689383          1.01
# 5        771608          1.12
# 6        437479          0.97
# 7      16718965          1.41
# 8    1439323776          0.39
# 9       1207359          0.73
# 10      3989167         -0.19
# 11      7496981          0.82
# 12   1380004385          0.99
# 13    273523615          1.07
# 14     83992949          1.30
# 15     40222493          2.32
# 16      8655535          1.60
# 17    126476461         -0.30
# 18     10203134          1.00
# 19     18776707          1.21
# 20      4270571          1.51
# 21      6524195          1.69
# 22      7275560          1.48
# 23      6825445         -0.44
# 24       649335          1.39
# 25     32365999          1.30
# 26       540544          1.81
# 27      3278290          1.65
# 28     54409800          0.67
# 29     29136808          1.85
# ...

# %%
sns.regplot(y=AP2['Population'],x=AP2['YearlyChange'])

plt.title('regression plot',fontsize=15,color='red') 
plt.xlabel('YearlyChange',fontsize=15) 
plt.ylabel('Population',fontsize=15)
plt.show()

# %% [markdown]
# # display the shape

# %%
x=AP2.iloc[:,:-1].values
y=AP2.iloc[:,1].values

# %%
x
# Out:
# array([[  38928346],
#        [   2963243],
#        [  10139177],
#        [   1701575],
#        [ 164689383],
#        [    771608],
#        [    437479],
#        [  16718965],
#        [1439323776],
#        [   1207359],
#        [   3989167],
#        [   7496981],
#        [1380004385],
#        [ 273523615],
#        [  83992949],
#        [  40222493],
#        [   8655535],
#        [ 126476461],
#        [  10203134],
#        [  18776707],
#        [   4270571],
#        [   6524195],
#        [   7275560],
#        [   6825445],
#        [    649335],
#        [  32365999],
#        [    540544],
#        [   3278290],
#        [  54409800],
#        [  29136808],
#        [  25778816],
#        [   5106626],
#        [ 220892340],
#        [ 109581078],
#        [   2881053],
#        [  34813871],
#        [   5850342],
#        [  51269185],
#        [  21413249],
#        [   5101414],
#        [  17500658],
#        [  23816775],
#        [   9537645],
# ...

# %%
print(x[:5])
# Out:
# [[ 38928346]
#  [  2963243]
#  [ 10139177]
#  [  1701575]
#  [164689383]]

# %%
print(x.shape)
# Out:
# (51, 1)

# %%
y
# Out:
# array([ 2.33,  0.19,  0.91,  3.68,  1.01,  1.12,  0.97,  1.41,  0.39,
#         0.73, -0.19,  0.82,  0.99,  1.07,  1.3 ,  2.32,  1.6 , -0.3 ,
#         1.  ,  1.21,  1.51,  1.69,  1.48, -0.44,  1.39,  1.3 ,  1.81,
#         1.65,  0.67,  1.85,  0.44,  2.65,  2.  ,  1.35,  1.73,  1.59,
#         0.79,  0.09,  0.42,  2.41,  2.52,  0.18,  2.32,  0.25,  1.96,
#         1.09,  1.5 ,  1.23,  1.48,  0.91,  2.28])

# %%
print(y[:5])
# Out:
# [2.33 0.19 0.91 3.68 1.01]

# %%
print(y.shape)
# Out:
# (51,)

# %% [markdown]
# #  import the library to train ,test and split

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# # perform the split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (38, 1)
# (13, 1)
# (38,)
# (13,)

# %% [markdown]
# # specify the split size manually by specifying the parameter of the test size

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
print(np.mean(x_train))
print(np.mean(x_test))
print(np.mean(y_train))
print(np.mean(y_test))
# Out:
# 103334610.175
# 46151851.63636363
# 1.15475
# 1.6790909090909094

# %% [markdown]
# # linear regression analysis

# %%
from sklearn.linear_model import LinearRegression
l=LinearRegression()
l.fit(x_train,y_train)
print('train test complete')
# Out:
# train test complete

# %%
y_pred=l.predict(x_test)

# %%
AP=pd.DataFrame({'Actual':y_test,'Predicted':y_pred})
AP
# Out:
#     Actual  Predicted
# 0     1.48   1.194972
# 1     0.91   1.193773
# 2     0.91   1.157261
# 3     1.81   1.197792
# 4     1.35   1.152134
# 5     1.96   1.197466
# 6     0.44   1.187224
# 7     2.28   1.185529
# 8     2.00   1.105526
# 9     1.65   1.196646
# 10    3.68   1.197306

# %%
from sklearn.metrics import mean_absolute_error
print('Mean Absolute Error',mean_absolute_error(y_test,y_pred))
# Out:
# Mean Absolute Error 0.7328078341152047

# %%
sns.regplot(x=y_test,y=y_pred)
plt.title('Regession Plot',size=15)
plt.ylabel('predicted',size=12)
plt.xlabel('actual',size=12)
plt.show()
